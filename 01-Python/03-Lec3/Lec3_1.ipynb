# %% [markdown]
# # Tkinter

# %% [markdown]
# Python has a lot of GUI frameworks, but Tkinter is the only framework that’s built into the Python standard library. Tkinter has several strengths. It’s cross-platform, so the same code works on Windows, macOS, and Linux. Visual elements are rendered using native operating system elements, so applications built with Tkinter look like they belong on the platform where they’re run.
#
# Although Tkinter is considered the de facto Python GUI framework, it’s not without criticism. One notable criticism is that GUIs built with Tkinter look outdated. If you want a shiny, modern interface, then Tkinter may not be what you’re looking for.
#
# However, Tkinter is lightweight and relatively painless to use compared to other frameworks. This makes it a compelling choice for building GUI applications in Python, especially for applications where a modern sheen is unnecessary, and the top priority is to quickly build something that’s functional and cross-platform.

# %% [markdown]
# # Show your project link

# %%
################################Creating of a small window with lable ################################
######################################################################################################



# Import all methods of the module  
from tkinter import *

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("Hello From Tkinter ")

# Adding lable to a specific window with a specific name 

label_1  =Label(window_1 , text = "Label1")

# using geomertry function to set the lable in a specific place [BOTTOM , LEFT , RIGHT] 

label_1.pack(side = TOP)

# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\ITI_Embedded_Linux\01-Python\03-Lec3\Lec3_1.ipynb Cell 5 in <cell line: 26>()
#      <a href='vscode-notebook-cell:/d%3A/ITI_Embedded_Linux/01-Python/03-Lec3/Lec3_1.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a> label_1.pack(side = TOP)
#      <a href='vscode-notebook-cell:/d%3A/ITI_Embedded_Linux/01-Python/03-Lec3/Lec3_1.ipynb#W5sZmlsZQ%3D%3D?line=24'>25</a> # Call the main loop which is used when the application is ready to run to keep the code displaying
# ---> <a href='vscode-notebook-cell:/d%3A/ITI_Embedded_Linux/01-Python/03-Lec3/Lec3_1.ipynb#W5sZmlsZQ%3D%3D?line=25'>26</a> window_1.mainloop()
#
# File c:\Users\AlaaElnagar\AppData\Local\Programs\Python\Python39\lib\tkinter\__init__.py:1421, in Misc.mainloop(self, n)
#    1419 def mainloop(self, n=0):
#    1420     """Call the mainloop of Tk."""
# -> 1421     self.tk.mainloop(n)
#
# ...

# %%
################################Controlling window geometery#########################################
#####################################################################################################


# Import all methods of the module  
from tkinter import *

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("Hello From Tkinter ")

# controlling window geometry in pixles 
window_1.geometry('100x200')   # width X heoght 

# Adding lable to a specific window with a specific name 

label_1  =Label(window_1 , text = "Label1")

# using geomertry function to set the lable in a specific place [BOTTOM , LEFT , RIGHT] 

label_1.pack(side = TOP)

# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()

# %%
################################Adding widget [button] to the window ###############################
#####################################################################################################
# Import all methods of the module  
from tkinter import *

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("Hello From Tkinter ")

# controlling window geometry in pixles 
window_1.geometry('1000x500')   # width X heoght 

# Adding lable to a specific window with a specific name 

label_1  =Label(window_1 , text = "Anis")

# Adding button to a specific window with a specific name and specific button name 

b1  =Button(window_1 , text = "AlaaElnaggar")

# using geomertry function to set the lable in a specific place [BOTTOM , LEFT , RIGHT] 

b1.pack(side = TOP)
label_1.pack(side = BOTTOM)

# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()

# %% [markdown]
# # Lab1
# - write a python module that generate window with three packed buttons left, right and Top
# - Window size is 500x500
# - window title welcome tkinter

# %%
################################Adding widget [button] to the window ###############################
#####################################################################################################
# Import all methods of the module  
from tkinter import *

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("welcome Tkinter ")

# controlling window geometry in pixles 
window_1.geometry('1000x500')   # width X heoght 

# Adding button to a specific window with a specific name and specific button name 

B_1  =Button(window_1 , text = "B1")
B_1.pack(side = TOP)

B_2  =Button(window_1 , text = "B2")
B_2.pack(side = LEFT)

B_3  =Button(window_1 , text = "B3")
B_3.pack(side = RIGHT)

# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()

# %%
################################Linking  widget [button] with actions ###############################
#####################################################################################################

from tkinter import *

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("welcome Tkinter ")

# controlling window geometry in pixles 
window_1.geometry('1000x500')   # width X heoght 

# Adding button to a specific window with a specific name and specific button name 
# bd border size
# destroy : delete the application 
B_1  =Button(window_1 , text = "Close the window" , bd = '5' , command = window_1.destroy)
B_1.pack(side = TOP)


# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()

# %%
################################Linking  widget [button] with actions ###############################
#####################################################################################################

from tkinter import *

def ButtonPressTracker():
    ButtonPressTracker.counter +=1 
    print("The button pressed" , ButtonPressTracker.counter)
ButtonPressTracker.counter =0

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("welcome Tkinter ")

# controlling window geometry in pixles 
window_1.geometry('1000x500')   # width X heoght 


B_1  =Button(window_1 , text = "Increment The button" , bd = '5' , command = ButtonPressTracker)
B_1.pack(side = TOP)

# Adding button to a specific window with a specific name and specific button name 
# bd border size
# destroy : delete the application 
B_2  =Button(window_1 , text = "Close the window" , bd = '5' , command = window_1.destroy)
B_2.pack(side = BOTTOM)


# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()
# Out:
# The button pressed 1
# The button pressed 2
# The button pressed 3
# The button pressed 4
# The button pressed 5
# The button pressed 6
# The button pressed 7
# The button pressed 8
# The button pressed 9
# The button pressed 10
# The button pressed 11
# The button pressed 12

# %%
################################ Adding image to a button  ##########################################
#####################################################################################################

from tkinter import *

def ButtonPressTracker():
    ButtonPressTracker.counter +=1 
    print("The button pressed" , ButtonPressTracker.counter)
ButtonPressTracker.counter =0

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("welcome Tkinter ")

# controlling window geometry in pixles 
window_1.geometry('500x500')   # width X height 

# Adding lable widget to the window_1
Label(window_1 , text = "Image Button " , font = ('Verdana', 30)).pack(side=TOP)

# Adding a photo image object to use image 
photo_1 = PhotoImage(file='iti.png')

# editing of the image resizing of it 
# resizing decreased by increasing the number 
photo_1 = photo_1.subsample(2,2)


B_1  =Button(window_1 , text = "Increment The button " , bd = '5' ,image=photo_1, command = ButtonPressTracker)

B_1.pack(side = TOP)

# Adding button to a specific window with a specific name and specific button name 
# bd border size
# destroy : delete the application 
B_2  =Button(window_1 , text = "Close the window" , bd = '5' , command = window_1.destroy)
B_2.pack(side = BOTTOM)


# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()

# %%
################################     Usage of colours      ##########################################
#####################################################################################################

from tkinter import *

def ButtonPressTracker():
    ButtonPressTracker.counter +=1 
    print("The button pressed" , ButtonPressTracker.counter)
ButtonPressTracker.counter =0

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("welcome Tkinter ")

# controlling window geometry in pixles 
window_1.geometry('500x500')   # width X height 

# Adding lable widget to the window_1
Label(window_1 , text = "Image Button " ,background="green" , fg="red" , font = ('Verdana', 15)).pack(side=TOP)

# Adding a photo image object to use image 
photo_1 = PhotoImage(file='iti.png')

# editing of the image resizing of it 
# resizing decreased by increasing the number 
photo_1 = photo_1.subsample(2,2)


B_1  =Button(window_1 , text = "Increment The button " ,background="blue" , fg="black" , bd = '5' ,image=photo_1, command = ButtonPressTracker)

B_1.pack(side = TOP)

# Adding button to a specific window with a specific name and specific button name 
# bd border size
# destroy : delete the application 
B_2  =Button(window_1 , text = "Close the window" ,background="green" , fg="red", bd = '5' , command = window_1.destroy)
B_2.pack(side = BOTTOM)


# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()

# %%
################################    Adjusting the location      ##########################################
#####################################################################################################

from tkinter import *

def ButtonPressTracker():
    ButtonPressTracker.counter +=1 
    print("The button pressed" , ButtonPressTracker.counter)
ButtonPressTracker.counter =0

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("welcome Tkinter ")

# controlling window geometry in pixles 
window_1.geometry('500x500')   # width X height 

# Adding lable widget to the window_1
Label(window_1 , text = "Image Button " ,background="green" , fg="red" , font = ('Verdana', 15)).pack(side=TOP)


# Adding a photo image object to use image 
photo_1 = PhotoImage(file='iti.png')

# editing of the image resizing of it 
# resizing decreased by increasing the number 
photo_1 = photo_1.subsample(2,2)


B_1  =Button(window_1 , text = "Increment The button " ,background="blue" , fg="black" , bd = '5' ,image=photo_1, command = ButtonPressTracker)

B_1.place(x= 50,y = 50)

# Adding button to a specific window with a specific name and specific button name 
# bd border size
# destroy : delete the application 
B_2  =Button(window_1 , text = "Close the window" ,background="green" , fg="red", bd = '5' , command = window_1.destroy)
B_2.place(x = 300,y = 400 )


# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()

# %%
################################            Anchor       ##########################################
###################################################################################################

from tkinter import *

def ButtonPressTracker():
    ButtonPressTracker.counter +=1 
    print("The button pressed" , ButtonPressTracker.counter)
ButtonPressTracker.counter =0

# construct main window through calling TK()
# window_1 = tk.Tk() for other python versions  
window_1 = Tk() 

# adding title to the window 

window_1.title("welcome Tkinter ")

# controlling window geometry in pixles 
window_1.geometry('200x200')   # width X height 

B_2  =Button(window_1 , text = "Close the window" ,background="green" , fg="red", bd = '5' , command = window_1.destroy)

# anchor [NW N NE W CENTER E SW S SE]
B_2.place(relx = 0.5,rely = 0, anchor = CENTER )


# Call the main loop which is used when the application is ready to run to keep the code displaying 
window_1.mainloop()

# %% [markdown]
# # Position widget
# - pack() organizes widgets in horizontal and vertical boxes that are limited to left, right, top, bottom positions. Each box is offset and relative to each other.
# - place() places widgets in a two dimensional grid using x and y absolute coordinates.
# - grid() locates widgets in a two dimensional grid using row and column absolute coordinates.
# - Important: pack(), place(), and grid() should not be combined in the same master window. Instead choose one and stick with it.

# %% [markdown]
# ## Vertical Positioning with Pack

# %%
################################            Packing       #########################################
###################################################################################################
from tkinter import *

root = Tk()

# adding title to the window 

root.title("welcome Tkinter ")

# controlling window geometry in pixles 
root.geometry('200x200')   # width X height 
test = Label(root, text="Red",width=5,height=2 ,bg="red", fg="white")
test.pack(side=TOP)
test = Label(root, text="Green", width=5,height=2 ,bg="green", fg="white")
test.pack(side=TOP)
test = Label(root, text="Purple", width=5,height=2 ,bg="purple", fg="white")
test.pack(side=TOP)

mainloop()

# %% [markdown]
# ## Side-by-Side Positioning with Pack

# %%
################################            Packing       #########################################
###################################################################################################
from tkinter import *

root = Tk()

# adding title to the window 

root.title("welcome Tkinter ")

# controlling window geometry in pixles 
root.geometry('200x200')   # width X height 
test = Label(root, text="Red",width=5,height=2 ,bg="red", fg="white")
test.pack(side=LEFT)
test = Label(root, text="Green", width=5,height=2 ,bg="green", fg="white")
test.pack(side=LEFT)
test = Label(root, text="Purple", width=5,height=2 ,bg="purple", fg="white")
test.pack(side=LEFT)

mainloop()

# %% [markdown]
# #### place() lets you position a widget either with absolute x,y  coordinates, or relative to another widget.

# %%
from tkinter import *
root = Tk()
# we can set the geometery as following 
root.geometry('250x200')
Label(root, text="Position 1 : x=0, y=0", bg="#FFFF00", fg="black").place(x=5, y=0)
Label(root, text="Position 2 : x=50, y=40", bg="#3300CC", fg="white").place(x=50, y=40)
Label(root, text="Position 3 : x=75, y=80", bg="#FF0099", fg="white").place(x=75, y=80)

root.mainloop()

# %% [markdown]
# # Positioning Widgets With Grid Layout Manager
# - grid() positions widgets in a two dimensional grid of rows and columns similar to a spreadsheet.

# %%
from tkinter import *
root = Tk()

Label(text="Position 1", bg="#FFF111", fg="black", width=10).grid(row=0, column=0)
Label(text="Position 2", bg="#AFFF00", fg="black", width=10).grid(row=0, column=1)
Label(text="Position 3", bg="#FFBF00", fg="black", width=10).grid(row=1, column=0)
Label(text="Position 4", bg="#CFFF00", fg="black", width=10).grid(row=1, column=1)
Label(text="Position 5", bg="#DFFF00", fg="black", width=10).grid(row=2, column=0)
Label(text="Position 6", bg="#EFFF00", fg="black", width=10).grid(row=2, column=1)
Label(text="Position 7", bg="#00F000", fg="black", width=10).grid(row=3, column=0)
Label(text="Position 8", bg="#FAEF00", fg="black", width=10).grid(row=3, column=1)
Label(text="Position 9", bg="#FFFF00", fg="black", width=10).grid(row=4, column=0)
Label(text="Position 10", bg="#FFFF00", fg="black", width=10).grid(row=4, column=1)
Label(text="Position 11", bg="#AAAF00", fg="black", width=10).grid(row=5, column=0)
Label(text="Position 12", bg="#FFFF00", fg="black", width=10).grid(row=5, column=1)
Label(text="Position 13", bg="#CCCE00", fg="black", width=10).grid(row=6, column=0)
Label(text="Position 14", bg="#FFFF00", fg="black", width=10).grid(row=6, column=1)
Label(text="Position 15", bg="#FFFF00", fg="black", width=10).grid(row=7, column=0)
Label(text="Position 16", bg="#FFFF00", fg="black", width=10).grid(row=7, column=1)
Label(text="Position 17", bg="#FFFF00", fg="black", width=10).grid(row=8, column=0)
Label(text="Position 18", bg="#FFFF00", fg="black", width=10).grid(row=8, column=1)
Label(text="Position 19", bg="#FFFF00", fg="black", width=10).grid(row=9, column=0)
Label(text="Position 20", bg="#FFFF00", fg="black", width=10).grid(row=9, column=1)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# d:\ITI_Embedded_Linux\01-Python\03-Lec3\Lec3_1.ipynb Cell 25 in <cell line: 25>()
#      <a href='vscode-notebook-cell:/d%3A/ITI_Embedded_Linux/01-Python/03-Lec3/Lec3_1.ipynb#X34sZmlsZQ%3D%3D?line=22'>23</a> Label(text="Position 20", bg="#FFFF00", fg="black", width=10).grid(row=9, column=1)
#      <a href='vscode-notebook-cell:/d%3A/ITI_Embedded_Linux/01-Python/03-Lec3/Lec3_1.ipynb#X34sZmlsZQ%3D%3D?line=23'>24</a> test = Label(root, text="Purple", width=5,height=2 ,bg="purple", fg="white")
# ---> <a href='vscode-notebook-cell:/d%3A/ITI_Embedded_Linux/01-Python/03-Lec3/Lec3_1.ipynb#X34sZmlsZQ%3D%3D?line=24'>25</a> test.pack(side=LEFT)
#      <a href='vscode-notebook-cell:/d%3A/ITI_Embedded_Linux/01-Python/03-Lec3/Lec3_1.ipynb#X34sZmlsZQ%3D%3D?line=25'>26</a> root.mainloop()
#
# ...

# %% [markdown]
# # The Entry widget is used to accept single-line text strings from a user.
#
# - If you want to display multiple lines of text that can be edited, then you should use the Text widget.
#
# - If you want to display one or more lines of text that cannot be modified by the user, then you should use the Label widget.

# %%
from tkinter import *

top = Tk()
L1 = Label(top, text="User Name")
L1.pack( side = LEFT)
E1 = Entry(top, bd =5)
E1.pack(side = RIGHT)

top.mainloop()

# %% [markdown]
# Methods: The various methods provided by the entry widget are:
#
# - get() : Returns the entry’s current text as a string.
# - insert ( index, ‘name’) : Inserts string ‘name’ before the character at the given index.

# %%
# Program to make a simple
# login screen

import tkinter as tk

root=tk.Tk()

# setting the windows size
root.geometry("300x100")

# declaring string variable
# for storing name and password
name_var=tk.StringVar()
passw_var=tk.StringVar()


# defining a function that will
# get the name and password and
# print them on the screen
def submit():

	name=name_var.get()
	password=passw_var.get()
	
	print("The name is : " + name)
	print("The password is : " + password)
	
	name_var.set("")
	passw_var.set("")
	
	
# creating a label for
# name using widget Label
name_label = tk.Label(root, text = 'Username', font=('calibre',10, 'bold'))

# creating a entry for input
# name using widget Entry
name_entry = tk.Entry(root,textvariable = name_var, font=('calibre',10,'normal'))

# creating a label for password
passw_label = tk.Label(root, text = 'Password', font = ('calibre',10,'bold'))

# creating a entry for password
passw_entry=tk.Entry(root, textvariable = passw_var, font = ('calibre',10,'normal'), show = '@')

# creating a button using the widget
# Button that will call the submit function
sub_btn=tk.Button(root,text = 'Submit', command = submit)

# placing the label and entry in
# the required position using grid
# method
name_label.grid(row=0,column=0)
name_entry.grid(row=0,column=1)
passw_label.grid(row=1,column=0)
passw_entry.grid(row=1,column=1)
sub_btn.grid(row=2,column=1)

# performing an infinite loop
# for the window to display
root.mainloop()

# %%
import tkinter
window_name=tkinter.Tk()   #creat object from the window 

window_name.geometry("120x120")
#tkinter.Radiobutton()
var=tkinter.IntVar()  #WE CANT ACCESS THE VAR WHICH HAVE THE VARIABLE  IN TK
var1=tkinter.IntVar()
def fun():
	global var
	if var.get()==0:
		print("led on")
	elif var.get()==1:
		print("led off")
def fun1():
	global var1
	if var1.get()==0:
		print("motor on")
	elif var1.get()==1:
		print("motor off")
RB1=tkinter.Radiobutton(window_name,value=0,variable=var,text="input1",command=fun)
RB1.grid(row=0,column=1)
RB2=tkinter.Radiobutton(window_name,value=1,variable=var,text="input2",command=fun)
RB2.grid(row=0,column=2)
#------------------------------------
RB3=tkinter.Radiobutton(window_name,value=0,variable=var1,text="input3",command =fun1)
RB3.grid(row=1,column=1)
RB4=tkinter.Radiobutton(window_name,value=1,variable=var1,text="input4",command =fun1)
RB4.grid(row=1,column=2)
#------------------------------------
window_name.mainloop()
# Out:
# led off
# motor on
# motor off
# led on
# led on
# led on
# led on
# led on
# led off
